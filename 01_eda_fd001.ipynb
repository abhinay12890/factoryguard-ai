# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Column names as defined by NASA
columns = ['engine_id', 'cycle'] + \
          [f'op_setting_{i}' for i in range(1, 4)] + \
          [f'sensor_{i}' for i in range(1, 22)]

# Load training data
train_df = pd.read_csv(
    '..data/raw/train_FD001.txt',
    sep=' ',
    header=None
)

# Drop completely empty columns (IMPORTANT FIX)
train_df = train_df.dropna(axis=1, how='all')

# Assign column names
train_df.columns = columns

train_df.head()
# Out:
#    engine_id  cycle  op_setting_1  op_setting_2  op_setting_3  sensor_1  \
# 0          1      1       -0.0007       -0.0004         100.0    518.67
# 1          1      2        0.0019       -0.0003         100.0    518.67
# 2          1      3       -0.0043        0.0003         100.0    518.67
# 3          1      4        0.0007        0.0000         100.0    518.67
# 4          1      5       -0.0019       -0.0002         100.0    518.67
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 0    641.82   1589.70   1400.60     14.62  ...     521.66    2388.02
# 1    642.15   1591.82   1403.14     14.62  ...     522.28    2388.07
# 2    642.35   1587.99   1404.20     14.62  ...     522.42    2388.03
# 3    642.35   1582.79   1401.87     14.62  ...     522.86    2388.08
# 4    642.37   1582.85   1406.22     14.62  ...     522.19    2388.04
#
#    sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  \
# 0    8138.62     8.4195       0.03        392       2388      100.0
# 1    8131.49     8.4318       0.03        392       2388      100.0
# 2    8133.23     8.4178       0.03        390       2388      100.0
# 3    8133.83     8.3682       0.03        392       2388      100.0
# 4    8133.80     8.4294       0.03        393       2388      100.0
#
#    sensor_20  sensor_21
# 0      39.06    23.4190
# 1      39.00    23.4236
# 2      38.95    23.3442
# 3      38.88    23.3739
# 4      38.90    23.4044
#
# [5 rows x 26 columns]

# %%
# Calculate max cycle per engine
max_cycle = train_df.groupby('engine_id')['cycle'].max()

# Create RUL column
train_df['RUL'] = train_df.apply(
    lambda row: max_cycle[row['engine_id']] - row['cycle'],
    axis=1
)

train_df[['engine_id', 'cycle', 'RUL']].head()
# Out:
#    engine_id  cycle    RUL
# 0          1      1  191.0
# 1          1      2  190.0
# 2          1      3  189.0
# 3          1      4  188.0
# 4          1      5  187.0

# %%
FAILURE_THRESHOLD = 24  # cycles (~24 hours)

train_df['failure'] = (train_df['RUL'] <= FAILURE_THRESHOLD).astype(int)

train_df['failure'].value_counts(normalize=True) * 100
# Out:
# failure
# 0    87.882313
# 1    12.117687
# Name: proportion, dtype: float64

# %%
train_df
# Out:
#        engine_id  cycle  op_setting_1  op_setting_2  op_setting_3  sensor_1  \
# 0              1      1       -0.0007       -0.0004         100.0    518.67
# 1              1      2        0.0019       -0.0003         100.0    518.67
# 2              1      3       -0.0043        0.0003         100.0    518.67
# 3              1      4        0.0007        0.0000         100.0    518.67
# 4              1      5       -0.0019       -0.0002         100.0    518.67
# ...          ...    ...           ...           ...           ...       ...
# 20626        100    196       -0.0004       -0.0003         100.0    518.67
# 20627        100    197       -0.0016       -0.0005         100.0    518.67
# 20628        100    198        0.0004        0.0000         100.0    518.67
# 20629        100    199       -0.0011        0.0003         100.0    518.67
# 20630        100    200       -0.0032       -0.0005         100.0    518.67
#
#        sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_14  sensor_15  \
# 0        641.82   1589.70   1400.60     14.62  ...    8138.62     8.4195
# 1        642.15   1591.82   1403.14     14.62  ...    8131.49     8.4318
# 2        642.35   1587.99   1404.20     14.62  ...    8133.23     8.4178
# 3        642.35   1582.79   1401.87     14.62  ...    8133.83     8.3682
# 4        642.37   1582.85   1406.22     14.62  ...    8133.80     8.4294
# ...         ...       ...       ...       ...  ...        ...        ...
# 20626    643.49   1597.98   1428.63     14.62  ...    8137.60     8.4956
# 20627    643.54   1604.50   1433.58     14.62  ...    8136.50     8.5139
# 20628    643.42   1602.46   1428.18     14.62  ...    8141.05     8.5646
# 20629    643.23   1605.26   1426.53     14.62  ...    8139.29     8.5389
# 20630    643.85   1600.38   1432.14     14.62  ...    8137.33     8.5036
#
#        sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  sensor_21  \
# 0           0.03        392       2388      100.0      39.06    23.4190
# 1           0.03        392       2388      100.0      39.00    23.4236
# 2           0.03        390       2388      100.0      38.95    23.3442
# 3           0.03        392       2388      100.0      38.88    23.3739
# 4           0.03        393       2388      100.0      38.90    23.4044
# ...          ...        ...        ...        ...        ...        ...
# 20626       0.03        397       2388      100.0      38.49    22.9735
# 20627       0.03        395       2388      100.0      38.30    23.1594
# 20628       0.03        398       2388      100.0      38.44    22.9333
# 20629       0.03        395       2388      100.0      38.29    23.0640
# 20630       0.03        396       2388      100.0      38.37    23.0522
#
#          RUL  failure
# 0      191.0        0
# 1      190.0        0
# 2      189.0        0
# 3      188.0        0
# 4      187.0        0
# ...      ...      ...
# 20626    4.0        1
# 20627    3.0        1
# 20628    2.0        1
# 20629    1.0        1
# 20630    0.0        1
#
# [20631 rows x 28 columns]

# %%
plt.figure(figsize=(18, 6))
(train_df.groupby("engine_id")["cycle"].max()).plot(kind="bar")
plt.ylabel("Max Cycle")
plt.title("Max Cycle per Engine")
plt.show()

# %%
train_df.columns
# Out:
# Index(['engine_id', 'cycle', 'op_setting_1', 'op_setting_2', 'op_setting_3',
#        'sensor_1', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_5', 'sensor_6',
#        'sensor_7', 'sensor_8', 'sensor_9', 'sensor_10', 'sensor_11',
#        'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15', 'sensor_16',
#        'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20', 'sensor_21', 'RUL',
#        'failure'],
#       dtype='object')

# %%
for x in train_df.columns:
  if x not in ["engine_id","cycle","RUL","failure"]:
    sns.histplot(train_df[x], kde=True)
    plt.title(f"Distribution of {x}")
    plt.xlabel(x)
    plt.ylabel("Frequency")
    plt.show()

# %%
temp_df=train_df.groupby(["engine_id","failure"])["cycle"].max().reset_index()
temp_df
# Out:
#      engine_id  failure  cycle
# 0            1        0    167
# 1            1        1    192
# 2            2        0    262
# 3            2        1    287
# 4            3        0    154
# ..         ...      ...    ...
# 195         98        1    156
# 196         99        0    160
# 197         99        1    185
# 198        100        0    175
# 199        100        1    200
#
# [200 rows x 3 columns]

# %%
pivot_df = temp_df.pivot(index="engine_id", columns="failure", values="cycle").reset_index()
pivot_df
# Out:
# failure  engine_id    0    1
# 0                1  167  192
# 1                2  262  287
# 2                3  154  179
# 3                4  164  189
# 4                5  244  269
# ..             ...  ...  ...
# 95              96  311  336
# 96              97  177  202
# 97              98  131  156
# 98              99  160  185
# 99             100  175  200
#
# [100 rows x 3 columns]

# %%
pivot_df["failure_run"]=pivot_df[1]-pivot_df[0]
pivot_df
# Out:
# failure  engine_id    0    1  failure_run
# 0                1  167  192           25
# 1                2  262  287           25
# 2                3  154  179           25
# 3                4  164  189           25
# 4                5  244  269           25
# ..             ...  ...  ...          ...
# 95              96  311  336           25
# 96              97  177  202           25
# 97              98  131  156           25
# 98              99  160  185           25
# 99             100  175  200           25
#
# [100 rows x 4 columns]

# %%
pivot_df[["engine_id",0,"failure_run"]].set_index("engine_id").plot(kind="bar",stacked=True,figsize=(18,6))
plt.ylabel("Cycles")
plt.title("Failure Run per Engine")
plt.show()
